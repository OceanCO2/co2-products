# %%
# %load_ext autoreload
# %autoreload 2

import co2_synthesis as cs
from co2_synthesis import images
import pathlib
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
url = "https://docs.google.com/spreadsheets/d/1rg9yf1IxSr6fI7UvbrbMqrywRgIPS240uaphIplUXBo/edit?gid=0"
df = cs.google_sheet.get_sheet_data(url, skiprows=1).dropna(subset=["card-title"])

# %%
cs.generate_page_main(url, False)
# Out:
# 2026-02-25 14:54:43.621 | INFO     | co2_synthesis.generate_page:generate_page_main:20 - Fetching data from Google Sheet: https://docs.google.com/spreadsheets/d/1rg9yf1IxSr6fI7UvbrbMqrywRgIPS240uaphIplUXBo/edit?gid=0
# 2026-02-25 14:54:44.521 | DEBUG    | co2_synthesis.images:process_images_in_df:41 - Processing image for SOCAT from https://socat.info/wp-content/uploads/2017/06/cropped-socat_cat.png
# 2026-02-25 14:54:44.521 | DEBUG    | co2_synthesis.images:process_images_in_df:41 - Processing image for LDEO Surface pCO2 Database from https://www.ncei.noaa.gov/access/ocean-carbon-acidification-data-system/oceans/LDEO_Underway_Database/LDEOv2019_map.jpg
# 2026-02-25 14:54:44.522 | DEBUG    | co2_synthesis.images:process_images_in_df:41 - Processing image for GLODAPv2 from https://glodap.info/wp-content/uploads/2017/09/cropped-glodap_logo_trans.png
# ...

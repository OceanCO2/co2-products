# %%
# %load_ext autoreload
# %autoreload 2

import co2_synthesis as cs
from co2_synthesis import images
import pathlib

# %%
url = "https://docs.google.com/spreadsheets/d/1rg9yf1IxSr6fI7UvbrbMqrywRgIPS240uaphIplUXBo/edit?gid=0"
df = cs.google_sheet.get_sheet_data(url, skiprows=1).dropna(subset=["card-title"])

# %%
cs.generate_page_main(url, False)
# Out:
# 2025-11-05 11:19:02.758 | DEBUG    | co2_synthesis.generate_page:generate_page_main:20 - Fetching data from Google Sheet: https://docs.google.com/spreadsheets/d/1rg9yf1IxSr6fI7UvbrbMqrywRgIPS240uaphIplUXBo/edit?gid=0
# 2025-11-05 11:19:03.771 | WARNING  | co2_synthesis.images:process_images_in_df:15 - Error processing image for OceanSODA-ETHZv2 from https://agupubs.onlinelibrary.wiley.com/cms/asset/7decc330-7468-429c-bae9-ac51b085be30/gbc21584-fig-0007-m.jpg: 403 Client Error: Forbidden for url: https://agupubs.onlinelibrary.wiley.com/cms/asset/7decc330-7468-429c-bae9-ac51b085be30/gbc21584-fig-0007-m.jpg
# 2025-11-05 11:19:03.904 | WARNING  | co2_synthesis.images:process_images_in_df:15 - Error processing image for Surface OA Indicators  from https://agupubs.onlinelibrary.wiley.com/cms/asset/9184aab2-af20-4a63-9a8f-d0a99a4602bc/jame21817-fig-0008-m.jpg: 403 Client Error: Forbidden for url: https://agupubs.onlinelibrary.wiley.com/cms/asset/9184aab2-af20-4a63-9a8f-d0a99a4602bc/jame21817-fig-0008-m.jpg
# 2025-11-05 11:19:04.053 | WARNING  | co2_synthesis.images:process_images_in_df:15 - Error processing image for Aragonite Climatology from https://agupubs.onlinelibrary.wiley.com/cms/asset/1787fd59-795c-4979-9565-6e7270b0fdbf/gbc20348-fig-0002-m.jpg: 403 Client Error: Forbidden for url: https://agupubs.onlinelibrary.wiley.com/cms/asset/1787fd59-795c-4979-9565-6e7270b0fdbf/gbc20348-fig-0002-m.jpg
# 2025-11-05 11:19:04.203 | WARNING  | co2_synthesis.images:process_images_in_df:15 - Error processing image for Preformed properties for marine organic matter and carbonate mineral cycling quantification from https://agupubs.onlinelibrary.wiley.com/cms/asset/a70dc130-3967-4e0c-bab1-fa5967af0a63/gbc21075-fig-0003-m.jpg: 403 Client Error: Forbidden for url: https://agupubs.onlinelibrary.wiley.com/cms/asset/a70dc130-3967-4e0c-bab1-fa5967af0a63/gbc21075-fig-0003-m.jpg
# 2025-11-05 11:19:04.423 | WARNING  | co2_synthesis.images:process_images_in_df:15 - Error processing image for Point B Time-series from https://upload.wikimedia.org/wikipedia/commons/a/ac/No_image_available.svg: cannot identify image file <_io.BytesIO object at 0x11f0f3740>
# 2025-11-05 11:19:04.449 | DEBUG    | co2_synthesis.generate_page:generate_page_main:29 - Retrieved 39 rows from Google Sheet.
# 1                                                                      2   \
# data-category                                           Data compilations
# card-title                                                          SOCAT
# card-subheading                                      Bakker et al. (2016)
# card-image                                               images/socat.png
# card-attribute.icon                                     fa-solid fa-globe
# card-attribute.label                                      Spatial domains
# card-attribute.value                         Open ocean, Coastal, Surface
# card-attribute.icon.1                         fa-solid fa-hourglass-start
# card-attribute.label.1                                Temporal resolution
# card-attribute.value.1                                         continuous
# card-attribute.icon.2                        fa-solid fa-ruler-horizontal
# card-attribute.label.2                                 Spatial resolution
# card-attribute.value.2
# card-attribute.icon.3                           fa-solid fa-calendar-days
# card-attribute.label.3                                             Period
# card-attribute.value.3                                        1960 - 2025
# card-summary            The largest collection of surface ocean carbon...
# card-citation                                        Bakker et al. (2016)
# card-citation-link                https://doi.org/10.5194/essd-8-383-2016
# card-data-access                                      https://socat.info/
# card-detail.title                                             Description
# card-detail.content     The Surface Ocean CO2 Atlas features surface f...
# card-detail.title.1                                             Reference
# card-detail.content.1   Bakker, D. C. E., Pfeil, B., Landa, C. S., Met...
#
# 1                                                                      3   \
# data-category                                           Data compilations
# card-title                                     LDEO Surface pCO2 Database
# card-subheading                                    Takahashi et a. (2009)
# card-image                          images/ldeo_surface_pco2_database.png
# card-attribute.icon                                     fa-solid fa-globe
# card-attribute.label                                      Spatial domains
# card-attribute.value                                  Open ocean, Surface
# card-attribute.icon.1                         fa-solid fa-hourglass-start
# card-attribute.label.1                                Temporal resolution
# card-attribute.value.1                                         continuous
# card-attribute.icon.2                        fa-solid fa-ruler-horizontal
# card-attribute.label.2                                 Spatial resolution
# card-attribute.value.2
# card-attribute.icon.3                           fa-solid fa-calendar-days
# card-attribute.label.3                                             Period
# card-attribute.value.3
# card-summary            The LDEO database reports pCO2 exclusively fro...
# card-citation                                      Takahashi et a. (2009)
# card-citation-link             https://doi.org/10.1016/j.dsr2.2008.12.009
# card-data-access        https://www.ncei.noaa.gov/data/oceans/ncei/oca...
# card-detail.title                                             Description
# card-detail.content     Dr. Taro Takahashi [LDEO, Palisades, New York]...
# card-detail.title.1                                             Reference
# card-detail.content.1   Takahashi, T., Sutherland, S. C., Wanninkhof, ...
#
# 1                                                                      4   \
# data-category                                           Data compilations
# card-title                                                       GLODAPv2
# card-subheading                                     Lauvset et al. (2024)
# card-image                                            images/glodapv2.png
# card-attribute.icon                                     fa-solid fa-globe
# card-attribute.label                                      Spatial domains
# card-attribute.value                             Open ocean, Water column
# card-attribute.icon.1                         fa-solid fa-hourglass-start
# card-attribute.label.1                                Temporal resolution
# card-attribute.value.1                                           discrete
# card-attribute.icon.2                        fa-solid fa-ruler-horizontal
# card-attribute.label.2                                 Spatial resolution
# card-attribute.value.2
# card-attribute.icon.3                           fa-solid fa-calendar-days
# card-attribute.label.3                                             Period
# card-attribute.value.3                                        1960 - 2024
# card-summary            Adjustments are applied by comparing data in t...
# card-citation                                       Lauvset et al. (2024)
# card-citation-link              https://doi.org/10.5194/essd-16-2047-2024
# card-data-access                                     https://glodap.info/
# card-detail.title                                             Description
# card-detail.content     The Global Ocean Data Analysis Project Version...
# card-detail.title.1                                             Reference
# card-detail.content.1   Lauvset, S. K., Lange, N., Tanhua, T., Bittig,...
#
# 1                                                                      5   \
# data-category                                           Data compilations
# card-title                                           World Ocean Database
# card-subheading                                    Mishonov et al. (2024)
# card-image                                images/world_ocean_database.png
# card-attribute.icon                                     fa-solid fa-globe
# card-attribute.label                                      Spatial domains
# card-attribute.value                             Open ocean, Water column
# card-attribute.icon.1                         fa-solid fa-hourglass-start
# card-attribute.label.1                                Temporal resolution
# card-attribute.value.1                                           discrete
# card-attribute.icon.2                        fa-solid fa-ruler-horizontal
# card-attribute.label.2                                 Spatial resolution
# card-attribute.value.2
# card-attribute.icon.3                           fa-solid fa-calendar-days
# card-attribute.label.3                                             Period
# card-attribute.value.3
# card-summary                     Similar to GLODAPv2, with no adjustments
# card-citation                                      Mishonov et al. (2024)
# card-citation-link                     https://doi.org/10.25923/z885-h264
# card-data-access        https://www.ncei.noaa.gov/products/world-ocean...
# card-detail.title                                             Description
# card-detail.content     In addition to the GLODAPv2 and JOA Suite, use...
# card-detail.title.1                                             Reference
# card-detail.content.1   Mishonov, A. V., Boyer, T. P., Baranova, O. K....
#
# 1                                                                      6   \
# data-category                                           Data compilations
# card-title                                                      SNAPO-CO2
# card-subheading                                        Metzl et al (2024)
# card-image                                           images/snapo-co2.png
# card-attribute.icon                                     fa-solid fa-globe
# card-attribute.label                                      Spatial domains
# card-attribute.value    Open ocean, Coastal, Surface, Water column, Re...
# card-attribute.icon.1                         fa-solid fa-hourglass-start
# card-attribute.label.1                                Temporal resolution
# card-attribute.value.1                               continuous, discrete
# card-attribute.icon.2                        fa-solid fa-ruler-horizontal
# card-attribute.label.2                                 Spatial resolution
# card-attribute.value.2
# card-attribute.icon.3                           fa-solid fa-calendar-days
# card-attribute.label.3                                             Period
# card-attribute.value.3                                          1993-2022
# card-summary            A compilation of cruises from multiple French ...
# card-citation                                          Metzl et al (2024)
# card-citation-link                https://doi.org/10.5194/essd-16-89-2024
# card-data-access                          https://doi.org/10.17882/102337
# card-detail.title                                             Description
# card-detail.content     Synthesis of 44,400 measurements of DIC and TA...
# card-detail.title.1                                             Reference
# card-detail.content.1   Metzl, N., Fin, J., Lo Monaco, C., Mignon, C.,...
#
# 1                                                                      7   \
# data-category                                           Data compilations
# card-title                                                       CODAP-NA
# card-subheading                                       Jiang et al. (2021)
# card-image                                            images/codap-na.png
# card-attribute.icon                                     fa-solid fa-globe
# card-attribute.label                                      Spatial domains
# card-attribute.value                                Coastal, Water column
# card-attribute.icon.1                         fa-solid fa-hourglass-start
# card-attribute.label.1                                Temporal resolution
# card-attribute.value.1                                           discrete
# card-attribute.icon.2                        fa-solid fa-ruler-horizontal
# card-attribute.label.2                                 Spatial resolution
# card-attribute.value.2
# card-attribute.icon.3                           fa-solid fa-calendar-days
# card-attribute.label.3                                             Period
# card-attribute.value.3                                        2003 - 2018
# card-summary            Like GLODAPv2, but for the North American coas...
# card-citation                                         Jiang et al. (2021)
# card-citation-link              https://doi.org/10.5194/essd-13-2777-2021
# card-data-access        https://www.ncei.noaa.gov/data/oceans/ncei/oca...
# card-detail.title                                             Description
# card-detail.content     Jiang et al. (2021) synthesized two decades of...
# card-detail.title.1                                             Reference
# card-detail.content.1   Jiang, L.-Q., Feely, R. A., Wanninkhof, R., Gr...
#
# 1                                                                      8   \
# data-category                                           Data compilations
# card-title                         Salish Sea Multi-stressor Data Product
# card-subheading                                        Alin et al. (2024)
# card-image              images/salish_sea_multi-stressor_data_product.png
# card-attribute.icon                                     fa-solid fa-globe
# card-attribute.label                                      Spatial domains
# card-attribute.value                                Coastal, Water column
# card-attribute.icon.1                         fa-solid fa-hourglass-start
# card-attribute.label.1                                Temporal resolution
# card-attribute.value.1                                           discrete
# card-attribute.icon.2                        fa-solid fa-ruler-horizontal
# card-attribute.label.2                                 Spatial resolution
# card-attribute.value.2
# card-attribute.icon.3                           fa-solid fa-calendar-days
# card-attribute.label.3                                             Period
# card-attribute.value.3
# card-summary            A data compilation and multi-stressor (OA, hyp...
# card-citation                                          Alin et al. (2024)
# card-citation-link               https://doi.org/10.5194/essd-16-837-2024
# card-data-access        https://www.ncei.noaa.gov/access/ocean-carbon-...
# card-detail.title                                             Description
# card-detail.content     Alin et al. (2024a) compiled data from 35 indi...
# card-detail.title.1                                             Reference
# card-detail.content.1   Alin, S. R., Newton, J. A., Feely, R. A., Gree...
#
# 1                                                                      9   \
# data-category                                                 Time series
# card-title                  pCO2 and pH Time-series from 40 Surface Buoys
# card-subheading                                      Sutton et al. (2019)
# card-image              images/pco2_and_ph_time-series_from_40_surface...
# card-attribute.icon                                     fa-solid fa-globe
# card-attribute.label                                      Spatial domains
# card-attribute.value                         Open ocean, Coastal, Surface
# card-attribute.icon.1                         fa-solid fa-hourglass-start
# card-attribute.label.1                                Temporal resolution
# card-attribute.value.1                                         continuous
# card-attribute.icon.2                        fa-solid fa-ruler-horizontal
# card-attribute.label.2                                 Spatial resolution
# card-attribute.value.2
# card-attribute.icon.3                           fa-solid fa-calendar-days
# card-attribute.label.3                                             Period
# card-attribute.value.3
# card-summary            Based on 40 moored surface pCO2 time-series, w...
# card-citation                                        Sutton et al. (2019)
# card-citation-link               https://doi.org/10.5194/essd-11-421-2019
# card-data-access        https://www.ncei.noaa.gov/data/oceans/ncei/oca...
# card-detail.title                                             Description
# card-detail.content     Sutton et al. (2019) established a living data...
# card-detail.title.1                                             Reference
# card-detail.content.1   Sutton, A. J., Feely, R. A., Maenner-Jones, S....
#
# 1                                                                      10  \
# data-category                                             Gridded surface
# card-title                                                       CSIR-ML6
# card-subheading                                      Gregor et al. (2019)
# card-image                                            images/csir-ml6.png
# card-attribute.icon                                     fa-solid fa-globe
# card-attribute.label                                      Spatial domains
# card-attribute.value                                  Open ocean, Surface
# card-attribute.icon.1                         fa-solid fa-hourglass-start
# card-attribute.label.1                                Temporal resolution
# card-attribute.value.1                                            monthly
# card-attribute.icon.2                        fa-solid fa-ruler-horizontal
# card-attribute.label.2                                 Spatial resolution
# card-attribute.value.2                                            1° x 1°
# card-attribute.icon.3                           fa-solid fa-calendar-days
# card-attribute.label.3                                             Period
# card-attribute.value.3                                        1982 - 2020
# card-summary            Various ML methods produce different results w...
# card-citation                                        Gregor et al. (2019)
# card-citation-link               https://doi.org/10.5194/gmd-12-5113-2019
# card-data-access        https://www.ncei.noaa.gov/data/oceans/ncei/oca...
# card-detail.title                                             Description
# card-detail.content     Provides monthly 1° × 1° estimates of surface ...
# card-detail.title.1                                             Reference
# card-detail.content.1   Gregor, L., Lebehot, A. D., Kok, S., and Schee...
#
# 1                                                                      11  \
# data-category                                             Gridded surface
# card-title                                               OceanSODA-ETHZv1
# card-subheading                                  Gregor and Gruber (2021)
# card-image                                    images/oceansoda-ethzv1.png
# card-attribute.icon                                     fa-solid fa-globe
# card-attribute.label                                      Spatial domains
# card-attribute.value                                  Open ocean, Surface
# card-attribute.icon.1                         fa-solid fa-hourglass-start
# card-attribute.label.1                                Temporal resolution
# card-attribute.value.1                                            monthly
# card-attribute.icon.2                        fa-solid fa-ruler-horizontal
# card-attribute.label.2                                 Spatial resolution
# card-attribute.value.2                                            1° x 1°
# card-attribute.icon.3                           fa-solid fa-calendar-days
# card-attribute.label.3                                             Period
# card-attribute.value.3                                        1982 - 2022
# card-summary            Temporal trends of DIC, TA, pCO2, pH, Ωarag, a...
# card-citation                                    Gregor and Gruber (2021)
# card-citation-link               https://doi.org/10.5194/essd-13-777-2021
# card-data-access        https://www.ncei.noaa.gov/data/oceans/ncei/oca...
# card-detail.title                                             Description
# card-detail.content     A monthly gridded global surface ocean data pr...
# card-detail.title.1                                             Reference
# card-detail.content.1   Gregor, L.; Gruber, N. OceanSODA-ETHZ: A Globa...
#
# 1                       ...  \
# data-category           ...
# card-title              ...
# card-subheading         ...
# card-image              ...
# card-attribute.icon     ...
# card-attribute.label    ...
# card-attribute.value    ...
# card-attribute.icon.1   ...
# card-attribute.label.1  ...
# card-attribute.value.1  ...
# card-attribute.icon.2   ...
# card-attribute.label.2  ...
# card-attribute.value.2  ...
# card-attribute.icon.3   ...
# card-attribute.label.3  ...
# card-attribute.value.3  ...
# card-summary            ...
# card-citation           ...
# card-citation-link      ...
# card-data-access        ...
# card-detail.title       ...
# card-detail.content     ...
# card-detail.title.1     ...
# card-detail.content.1   ...
#
# 1                                                                      31  \
# data-category                                             Gridded surface
# card-title                                                    UoEX-Watson
# card-subheading                                       Watson et al (2020)
# card-image                                         images/uoex-watson.png
# card-attribute.icon                                     fa-solid fa-globe
# card-attribute.label                                      Spatial domains
# card-attribute.value                                           Open ocean
# card-attribute.icon.1                         fa-solid fa-hourglass-start
# card-attribute.label.1                                Temporal resolution
# card-attribute.value.1                                            monthly
# card-attribute.icon.2                        fa-solid fa-ruler-horizontal
# card-attribute.label.2                                 Spatial resolution
# card-attribute.value.2                                            1° x 1°
# card-attribute.icon.3                           fa-solid fa-calendar-days
# card-attribute.label.3                                             Period
# card-attribute.value.3                                          1985-2019
# card-summary            Air-sea fluxes of CO2 with adjusted skin tempe...
# card-citation                                         Watson et al (2020)
# card-citation-link                     https://doi.org/10.25921/2dp5-xm29
# card-data-access        https://www.ncei.noaa.gov/data/oceans/ncei/oca...
# card-detail.title                                             Description
# card-detail.content     This is a gridded estimate of the atmosphere-o...
# card-detail.title.1                                             Reference
# card-detail.content.1   Watson, A. J., Schuster, U., Shutler, J. D., H...
#
# 1                                                                      32  \
# data-category                                                 Time series
# card-title                                            Point B Time-series
# card-subheading                                  Kapsenberg et al. (2017)
# card-image              https://upload.wikimedia.org/wikipedia/commons...
# card-attribute.icon                                     fa-solid fa-globe
# card-attribute.label                                      Spatial domains
# card-attribute.value                                              Coastal
# card-attribute.icon.1                         fa-solid fa-hourglass-start
# card-attribute.label.1                                Temporal resolution
# card-attribute.value.1                                           discrete
# card-attribute.icon.2                        fa-solid fa-ruler-horizontal
# card-attribute.label.2                                 Spatial resolution
# card-attribute.value.2
# card-attribute.icon.3                           fa-solid fa-calendar-days
# card-attribute.label.3                                             Period
# card-attribute.value.3
# card-summary            Carbonate chemistry at a coastal site of the B...
# card-citation                                    Kapsenberg et al. (2017)
# card-citation-link                 https://doi.org/10.5194/os-13-411-2017
# card-data-access                  https://doi.org/10.1594/PANGAEA.727120
# card-detail.title                                             Description
# card-detail.content     The Point B Time-series documents the carbonat...
# card-detail.title.1                                             Reference
# card-detail.content.1   Kapsenberg, L., Alliouane, S., Gazeau, F., Mou...
#
# 1                                                                      33  \
# data-category                                                 Time series
# card-title                                         Ny-Ålesund Time-series
# card-subheading                                     Gattuso et al. (2023)
# card-image                              images/ny-_lesund_time-series.png
# card-attribute.icon                                     fa-solid fa-globe
# card-attribute.label                                      Spatial domains
# card-attribute.value                                              Coastal
# card-attribute.icon.1                         fa-solid fa-hourglass-start
# card-attribute.label.1                                Temporal resolution
# card-attribute.value.1                               continuous, discrete
# card-attribute.icon.2                        fa-solid fa-ruler-horizontal
# card-attribute.label.2                                 Spatial resolution
# card-attribute.value.2
# card-attribute.icon.3                           fa-solid fa-calendar-days
# card-attribute.label.3                                             Period
# card-attribute.value.3
# card-summary            Carbonate chemistry at a coastal site of Kongs...
# card-citation                                       Gattuso et al. (2023)
# card-citation-link              https://doi.org/10.5194/essd-15-2809-2023
# card-data-access                  https://doi.org//10.1594/PANGAEA.957028
# card-detail.title                                             Description
# card-detail.content     The Ny-Ålesund Time-series documents the carbo...
# card-detail.title.1                                             Reference
# card-detail.content.1   Gattuso, J.-P., Alliouane, S., and Fischer, P....
#
# 1                                                                      34  \
# data-category                                             Gridded surface
# card-title                                                   CMEMS-LSCEv1
# card-subheading                                        Chau et al. (2022)
# card-image                                        images/cmems-lscev1.png
# card-attribute.icon                                     fa-solid fa-globe
# card-attribute.label                                      Spatial domains
# card-attribute.value                         Open ocean, Coastal, Surface
# card-attribute.icon.1                         fa-solid fa-hourglass-start
# card-attribute.label.1                                Temporal resolution
# card-attribute.value.1                               monthly, climatology
# card-attribute.icon.2                        fa-solid fa-ruler-horizontal
# card-attribute.label.2                                 Spatial resolution
# card-attribute.value.2                                            1° x 1°
# card-attribute.icon.3                           fa-solid fa-calendar-days
# card-attribute.label.3                                             Period
# card-attribute.value.3                                        1985 - 2019
# card-summary            seamless reconstruction from coastal to open o...
# card-citation                                          Chau et al. (2022)
# card-citation-link                https://doi.org/10.5194/bg-19-1087-2022
# card-data-access        https://data.ipsl.fr/catalog/srv/eng/catalog.s...
# card-detail.title                                             Description
# card-detail.content     Monthly surface ocean pCO2 and air–sea CO2 flu...
# card-detail.title.1                                             Reference
# card-detail.content.1   Chau, T.-T.-T., Gehlen, M., and Chevallier, F....
#
# 1                                                                      35  \
# data-category                                             Gridded surface
# card-title                                                   CMEMS-LSCEv2
# card-subheading                                        Chau et al. (2024)
# card-image                                        images/cmems-lscev2.png
# card-attribute.icon                                     fa-solid fa-globe
# card-attribute.label                                      Spatial domains
# card-attribute.value                         Open ocean, Coastal, Surface
# card-attribute.icon.1                         fa-solid fa-hourglass-start
# card-attribute.label.1                                Temporal resolution
# card-attribute.value.1                               monthly, climatology
# card-attribute.icon.2                        fa-solid fa-ruler-horizontal
# card-attribute.label.2                                 Spatial resolution
# card-attribute.value.2                                      0.25° x 0.25°
# card-attribute.icon.3                           fa-solid fa-calendar-days
# card-attribute.label.3                                             Period
# card-attribute.value.3                                        1985 - 2025
# card-summary            Yearly extension of time-series & monthly reco...
# card-citation                                          Chau et al. (2024)
# card-citation-link               https://doi.org/10.5194/essd-16-121-2024
# card-data-access                       https://doi.org/10.48670/moi-00047
# card-detail.title                                             Description
# card-detail.content     CMEMS-LSCEv2 corresponds to the latest version...
# card-detail.title.1                                             Reference
# card-detail.content.1   Chau, T.-T.-T., Gehlen, M., Metzl, N., and Che...
#
# 1                                                                      36  \
# data-category                                          Gridded subsurface
# card-title                                           GLODAPv2 Climatology
# card-subheading                                     Lauvset et al. (2016)
# card-image                                images/glodapv2_climatology.png
# card-attribute.icon                                     fa-solid fa-globe
# card-attribute.label                                      Spatial domains
# card-attribute.value                             Open ocean, Water column
# card-attribute.icon.1                         fa-solid fa-hourglass-start
# card-attribute.label.1                                Temporal resolution
# card-attribute.value.1                                        climatology
# card-attribute.icon.2                        fa-solid fa-ruler-horizontal
# card-attribute.label.2                                 Spatial resolution
# card-attribute.value.2                                            1° x 1°
# card-attribute.icon.3                           fa-solid fa-calendar-days
# card-attribute.label.3                                             Period
# card-attribute.value.3                                               2002
# card-summary            Ocean interior climatology for multiple variab...
# card-citation                                       Lauvset et al. (2016)
# card-citation-link                https://doi.org/10.5194/essd-8-325-2016
# card-data-access        https://www.ncei.noaa.gov/data/oceans/ncei/oca...
# card-detail.title                                             Description
# card-detail.content     Lauvset et al. (2016) generated a comprehensiv...
# card-detail.title.1                                             Reference
# card-detail.content.1   Lauvset, S. K., Key, R. M., Olsen, A., van Heu...
#
# 1                                                                      37  \
# data-category                                             Gridded surface
# card-title                                                  Stepwise-FFNN
# card-subheading                                       Zhong et al. (2022)
# card-image                                       images/stepwise-ffnn.png
# card-attribute.icon                                     fa-solid fa-globe
# card-attribute.label                                      Spatial domains
# card-attribute.value                                  Open ocean, Surface
# card-attribute.icon.1                         fa-solid fa-hourglass-start
# card-attribute.label.1                                Temporal resolution
# card-attribute.value.1                                            monthly
# card-attribute.icon.2                        fa-solid fa-ruler-horizontal
# card-attribute.label.2                                 Spatial resolution
# card-attribute.value.2                                            1° x 1°
# card-attribute.icon.3                           fa-solid fa-calendar-days
# card-attribute.label.3                                             Period
# card-attribute.value.3                                        1992 - 2024
# card-summary            ML-based selection of predictors considering r...
# card-citation                                         Zhong et al. (2022)
# card-citation-link             http://doi.org/10.12157/IOCAS.20250814.001
# card-data-access               http://doi.org/10.12157/IOCAS.20250814.001
# card-detail.title                                             Description
# card-detail.content     A monthly global 1° × 1° surface ocean pCO2 pr...
# card-detail.title.1                                             Reference
# card-detail.content.1   Zhong, G., Li, X., Song, J., Qu, B., Wang, F.,...
#
# 1                                                                      38  \
# data-category                                                 Model-based
# card-title                          Monthly Interior Ocean pH Climatology
# card-subheading                                       Zhong et al. (2025)
# card-image               images/monthly_interior_ocean_ph_climatology.png
# card-attribute.icon                                     fa-solid fa-globe
# card-attribute.label                                      Spatial domains
# card-attribute.value                             Open ocean, Water column
# card-attribute.icon.1                         fa-solid fa-hourglass-start
# card-attribute.label.1                                Temporal resolution
# card-attribute.value.1                                            monthly
# card-attribute.icon.2                        fa-solid fa-ruler-horizontal
# card-attribute.label.2                                 Spatial resolution
# card-attribute.value.2                                            1° x 1°
# card-attribute.icon.3                           fa-solid fa-calendar-days
# card-attribute.label.3                                             Period
# card-attribute.value.3                                        1992 - 2020
# card-summary            Temporal variability of pH in the interior oce...
# card-citation                                         Zhong et al. (2025)
# card-citation-link             http://doi.org/10.12157/IOCAS.20230720.001
# card-data-access               http://doi.org/10.12157/IOCAS.20230720.001
# card-detail.title                                             Description
# card-detail.content     A monthly 1° × 1° gridded global seawater pH (...
# card-detail.title.1                                             Reference
# card-detail.content.1   Zhong, G., Li, X., Song, J., Qu, B., Wang, F.,...
#
# 1                                                                      39  \
# data-category                                             Gridded surface
# card-title                                                        JMA-MLR
# card-subheading                                        Iida et al. (2021)
# card-image                                             images/jma-mlr.png
# card-attribute.icon                                     fa-solid fa-globe
# card-attribute.label                                      Spatial domains
# card-attribute.value                                  Open ocean, Surface
# card-attribute.icon.1                         fa-solid fa-hourglass-start
# card-attribute.label.1                                Temporal resolution
# card-attribute.value.1                                            monthly
# card-attribute.icon.2                        fa-solid fa-ruler-horizontal
# card-attribute.label.2                                 Spatial resolution
# card-attribute.value.2                                            1° x 1°
# card-attribute.icon.3                           fa-solid fa-calendar-days
# card-attribute.label.3                                             Period
# card-attribute.value.3                                          1990-2023
# card-summary            Temporal trends of DIC, TA, pCO2, air-sea CO2 ...
# card-citation                                          Iida et al. (2021)
# card-citation-link             https://doi.org/10.1007/s10872-020-00571-5
# card-data-access               https://doi.org/10.1007/s10872-020-00571-5
# card-detail.title                                             Description
# card-detail.content     Iida et al. (2021) developed a monthly data pr...
# card-detail.title.1                                             Reference
# card-detail.content.1   Iida, Y., Takatani, Y., Kojima, A., and Ishii,...
#
# 1                                                                      40
# data-category                                             Gridded surface
# card-title                                        ULB-SOM-FFN-Coastalv2.1
# card-subheading                                    Roobaert et al. (2024)
# card-image                             images/ulb-som-ffn-coastalv2_1.png
# card-attribute.icon                                     fa-solid fa-globe
# card-attribute.label                                      Spatial domains
# card-attribute.value                                              Coastal
# card-attribute.icon.1                         fa-solid fa-hourglass-start
# card-attribute.label.1                                Temporal resolution
# card-attribute.value.1                                continuous, monthly
# card-attribute.icon.2                        fa-solid fa-ruler-horizontal
# card-attribute.label.2                                 Spatial resolution
# card-attribute.value.2                                              0.25°
# card-attribute.icon.3                           fa-solid fa-calendar-days
# card-attribute.label.3                                             Period
# card-attribute.value.3                                          1982-2020
# card-summary            Global temporal trends of coastal pCO2 and air...
# card-citation                                      Roobaert et al. (2024)
# card-citation-link                     https://doi.org/10.25921/4sde-p068
# card-data-access        https://www.ncei.noaa.gov/access/metadata/land...
# card-detail.title                                             Description
# card-detail.content     Roobaert et al. (2024) present high-resolution...
# card-detail.title.1                                             Reference
# card-detail.content.1   Roobaert, A.: Regnier, P., Landschützer, P., L...
#
# [24 rows x 39 columns]
# 2025-11-05 11:19:05.875 | INFO     | co2_synthesis.generate_page:generate_page_main:43 - Downloaded Google Sheet as Excel file for backup.
